# %% [markdown]
# # Partially-Observed Planning from Pixels with JaxPlan

# %% [markdown]
# In this notebook, we learn a mapping from pixels to RDDL states in Pong and then use this mapping to plan directly from images.
# The overall process is:
# 1. Collect data of (state, image) pairs
# 2. Train a CNN to map image -> state
# 3. Use the CNN to map real-time images back to states and do MPC control from these states.
#
# Note: it is highly recommended to run this notebook in an environment with GPU support.

# %% [markdown]
# ## Learning to Predict RDDL State from Pixels

# %% [markdown]
# Install the required packages:

# %%
# %pip install --quiet --upgrade pip
# %pip install --quiet pyRDDLGym rddlrepository pyRDDLgym-jax
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Next, import the required packages:

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from IPython.display import Image
import os
import PIL
from tqdm import tqdm
import numpy as np
import jax
import jax.numpy as jnp
from flax import linen as nn
import optax

import pyRDDLGym
from pyRDDLGym.core.visualizer.movie import MovieGenerator
from pyRDDLGym_jax.core.planner import JaxBackpropPlanner, JaxOnlineController, load_config_from_string

# %% [markdown]
# Now, let's collect some data from a random policy. We concatenate ``obs_t, obs_{t + 1}`` as separate channels to learn the ball velocities:

# %%
# resize image, make grayscale and normalize to [0, 1]
def preprocess_frame(img, size=(64, 64)):
    img = img.convert("L").resize(size, PIL.Image.BILINEAR)
    return np.asarray(img, dtype=np.float32) / 255.0

env = pyRDDLGym.make('Pong_arcade', '0', vectorized=True)
env._visualizer._ball_radius *= 2

# collect transitions of (state, obs) pairs: stack previous and current images to obs
n_samples = 2000
states, obss = [], []
while True:
    env.reset()
    prev_obs = preprocess_frame(env.render())[..., None]
    for _ in range(env.horizon):
        action = {'move': np.random.randint(-1, 2)}
        state, _, term, trunc, _ = env.step(action)
        obs = preprocess_frame(env.render())[..., None]
        states.append(np.concatenate([np.reshape(v, (-1,)) for v in state.values()]))
        obss.append(np.concatenate([prev_obs, obs], axis=-1))
        prev_obs = obs
        if term or trunc or np.any(state['ball-x'] > 1) or len(states) >= n_samples: break
    if len(states) >= n_samples: break
env.close()
data = {'states': np.array(states), 'obs': np.array(obss)}

# %% [markdown]
# We proceed to train on mini-batches of (state, obs) pairs:

# %%
def batch_sampler(data, batch_size=32):
    indices = np.arange(data['states'].shape[0])
    np.random.default_rng().shuffle(indices)
    for i in range(0, len(indices) - batch_size, batch_size):
        idx = indices[i:i+batch_size]
        yield (data['states'][idx], data['obs'][idx])
print(', '.join(str(np.shape(arr)) for arr in next(batch_sampler(data))))
# Out:
# (32, 5), (32, 64, 64, 2)

# %% [markdown]
# We will train a convolutional neural network to map image to state:

# %%
class PongStateEncoder(nn.Module):
    low = jnp.array([[0., 0., -1., -1., 0.]])
    high = jnp.array([[1., 1., 1., 1., 0.8]])
    
    @nn.compact
    def __call__(self, x):
        x = nn.Conv(16, kernel_size=(3, 3), strides=(2, 2))(x)
        x = nn.relu(x)
        x = nn.Conv(32, kernel_size=(3, 3), strides=(2, 2))(x)
        x = nn.relu(x)
        x = nn.Conv(64, kernel_size=(3, 3), strides=(2, 2))(x)
        x = nn.relu(x)
        x = x.reshape((x.shape[0], -1))
        x = nn.Dense(128)(x)
        x = nn.relu(x)
        x = nn.Dense(5)(x)
        return self.low + (self.high - self.low) * nn.sigmoid(x)
encoder = PongStateEncoder()
encoder_fn = jax.jit(encoder.apply)

# %% [markdown]
# We train using ADAM using the MSE between the predicted and actual state for a given image:

# %%
optimizer = optax.adam(0.001)
@jax.jit
def update_fn(params, opt_state, obs, state):
    loss, grads = jax.value_and_grad(
        lambda p, o, s: jnp.mean(jnp.square(encoder_fn(p, o) - s)))(params, obs, state)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss

# %% [markdown]
# Let's now train the CNN:

# %%
params = encoder.init(jax.random.PRNGKey(0), jnp.zeros((32, 64, 64, 2)))
opt_state = optimizer.init(params)
for _ in (pbar := tqdm(range(500))):
    ep_loss = 0
    for it, (states, obs) in enumerate(batch_sampler(data)):
        params, opt_state, loss = update_fn(params, opt_state, obs, states)
        ep_loss += float(loss)
    pbar.set_postfix(loss=ep_loss / float(it))
# Out:
# 100%|██████████| 500/500 [02:01<00:00,  4.13it/s, loss=1.78e-5]

# %% [markdown]
# ## MPC from Pixels with JaxPlan using Trained State Predictor

# %% [markdown]
# We train an MPC controller that takes Pong screen images as input, mapes the back to states and computes an optimal action. Let's initialize the controller:

# %%
config_str = """
[Compiler]
print_warnings=False
[Planner]
method='JaxStraightLinePlan'
optimizer_kwargs={'learning_rate': 0.01}
batch_size_train=16
batch_size_test=16
rollout_horizon=20
[Optimize]
key=42
epochs=50
"""
planner_args, _, train_args = load_config_from_string(config_str)
planner = JaxBackpropPlanner(rddl=env.model, **planner_args)
agent = JaxOnlineController(planner, print_summary=False, print_progress=False, **train_args)

# %% [markdown]
# Finally, we run the controller, first inferring the ground truth RDDL state from consecutive image frames:

# %%
# set visualizer
if not os.path.exists('frames'):
    os.makedirs('frames')
recorder = MovieGenerator("frames", "pong_pomdp", max_frames=100)
env.set_visualizer(viz=None, movie_gen=recorder)

# convert array state to dict
def unflatten_state(state_flat):
    return {'ball-x': state_flat[0:1], 'ball-y': state_flat[1:2], 
            'vel-x': state_flat[2:3], 'vel-y': state_flat[3:4], 'paddle-y': state_flat[4:5]}    

state, _ = env.reset(seed=0)
prev_obs = preprocess_frame(env.render())[..., None]
for step in range(100):

    # predict state from obs
    obs = preprocess_frame(env.render())[..., None]
    encoder_obs = np.concatenate([prev_obs, obs], axis=-1)[None]
    state_flat = np.concatenate([np.reshape(v, (-1,)) for v in state.values()])
    state_pred = encoder_fn(params, encoder_obs).reshape((-1,))
    print(f"Step {step}, Pred state: {state_pred}, True state: {state_flat}")
    
    # use this state to select an action from the mpc controller
    action = agent.sample_action(unflatten_state(state_pred))
    state, *_ = env.step(action)
    prev_obs = obs
env.close()
Image(filename='frames/pong_pomdp_0.gif')
# Out:
# Step 0, Pred state: [0.50280267 0.4991081  0.00414813 0.00478196 0.39708975], True state: [0.5  0.5  0.03 0.01 0.4 ]
# Step 1, Pred state: [0.5301221  0.5096614  0.03090119 0.01038992 0.39973447], True state: [0.53 0.51 0.03 0.01 0.4 ]
# Step 2, Pred state: [0.5592434  0.5185668  0.03155649 0.01006091 0.4005178 ], True state: [0.56 0.52 0.03 0.01 0.4 ]
# Step 3, Pred state: [0.59053254 0.5273091  0.03101099 0.00978029 0.44123417], True state: [0.59 0.53 0.03 0.01 0.44]
# Step 4, Pred state: [0.6238111  0.539288   0.03151011 0.01029265 0.4392684 ], True state: [0.62 0.54 0.03 0.01 0.44]
# Step 5, Pred state: [0.6532244  0.5496735  0.03174639 0.01164579 0.47943026], True state: [0.65 0.55 0.03 0.01 0.48]
# Step 6, Pred state: [0.6822842  0.56209505 0.03120911 0.01203501 0.44016916], True state: [0.68 0.56 0.03 0.01 0.44]
# Step 7, Pred state: [0.7122234  0.56806004 0.03184211 0.01127172 0.47956058], True state: [0.71 0.57 0.03 0.01 0.48]
# Step 8, Pred state: [0.74301356 0.57755446 0.02963471 0.01136708 0.48016405], True state: [0.74 0.58 0.03 0.01 0.48]
# Step 9, Pred state: [0.7723864  0.58595294 0.02840579 0.01066947 0.52032596], True state: [0.77 0.59 0.03 0.01 0.52]
# Step 10, Pred state: [0.80624753 0.59844697 0.0320555  0.0107311  0.5624153 ], True state: [0.8  0.6  0.03 0.01 0.56]
# Step 11, Pred state: [0.83398473 0.6095182  0.03153932 0.01022601 0.60126287], True state: [0.83 0.61 0.03 0.01 0.6 ]
# Step 12, Pred state: [0.86048645 0.61907595 0.03252172 0.00992429 0.6430894 ], True state: [0.86 0.62 0.03 0.01 0.64]
# Step 13, Pred state: [0.88893205 0.6310571  0.03085613 0.00880635 0.64247876], True state: [0.89 0.63 0.03 0.01 0.64]
# Step 14, Pred state: [0.91971403 0.6363846  0.0314312  0.0097084  0.61682093], True state: [0.92 0.64 0.03 0.01 0.6 ]
# Step 15, Pred state: [0.9532906  0.6511382  0.03514194 0.01039243 0.6459305 ], True state: [0.95 0.65 0.03 0.01 0.64]
# Step 16, Pred state: [0.98243403 0.6664703  0.03845417 0.01162922 0.6404587 ], True state: [0.98 0.66 0.03 0.01 0.64]
# Step 17, Pred state: [ 0.9931797   0.6724258  -0.01043355  0.00964093  0.64394623], True state: [ 0.99       0.67      -0.03       0.0182177  0.64     ]
# Step 18, Pred state: [ 0.97622013  0.6826498  -0.02617097  0.00942492  0.62380743], True state: [ 0.96       0.6882177 -0.03       0.0182177  0.6      ]
# Step 19, Pred state: [ 0.953013    0.70143205 -0.03513253  0.01668298  0.6120209 ], True state: [ 0.93       0.7064354 -0.03       0.0182177  0.6      ]
# Step 20, Pred state: [ 0.90449494  0.7154335  -0.02055335  0.01650989  0.5688328 ], True state: [ 0.9        0.7246531 -0.03       0.0182177  0.56     ]
# Step 21, Pred state: [ 0.87204045  0.73227215 -0.02447814  0.01472366  0.554859  ], True state: [ 0.87       0.7428708 -0.03       0.0182177  0.56     ]
# Step 22, Pred state: [ 0.84997904  0.7598628  -0.02562916  0.01887512  0.554065  ], True state: [ 0.84        0.76108851 -0.03        0.0182177   0.52      ]
# Step 23, Pred state: [ 0.823485    0.78363603 -0.02694207  0.0209043   0.4767986 ], True state: [ 0.81        0.77930621 -0.03        0.0182177   0.48      ]
# Step 24, Pred state: [ 0.78784305  0.79807115 -0.02995026  0.01905799  0.4447678 ], True state: [ 0.78        0.79752391 -0.03        0.0182177   0.44      ]
# Step 25, Pred state: [ 0.749845    0.815999   -0.02919465  0.02001083  0.43791553], True state: [ 0.75        0.81574161 -0.03        0.0182177   0.44      ]
# Step 26, Pred state: [ 0.7084683   0.84207976 -0.03476918  0.02200675  0.39842173], True state: [ 0.72        0.83395931 -0.03        0.0182177   0.4       ]
# Step 27, Pred state: [ 0.69475675  0.85078    -0.03198642  0.0182941   0.39726028], True state: [ 0.69        0.85217701 -0.03        0.0182177   0.4       ]
# Step 28, Pred state: [ 0.6606314   0.8757828  -0.02640879  0.01754272  0.35939392], True state: [ 0.66        0.87039471 -0.03        0.0182177   0.36      ]
# Step 29, Pred state: [ 0.63435215  0.8916964  -0.02559382  0.02230716  0.3641289 ], True state: [ 0.63        0.88861241 -0.03        0.0182177   0.36      ]
# Step 30, Pred state: [ 0.5932376   0.9011343  -0.03264213  0.01811886  0.33103508], True state: [ 0.6         0.90683012 -0.03        0.0182177   0.32      ]
# Step 31, Pred state: [ 0.57600725  0.9199518  -0.02488738  0.02665412  0.27128902], True state: [ 0.57        0.92504782 -0.03        0.0182177   0.28      ]
# Step 32, Pred state: [ 0.5254982   0.9423342  -0.03211677  0.02121961  0.2705146 ], True state: [ 0.54        0.94326552 -0.03        0.0182177   0.28      ]
# Step 33, Pred state: [ 0.49103576  0.96521705 -0.0292654   0.01830542  0.2285577 ], True state: [ 0.51        0.96148322 -0.03        0.0182177   0.24      ]
# Step 34, Pred state: [ 0.47657835  0.9839299  -0.02351451  0.01349723  0.2060267 ], True state: [ 0.48        0.97970092 -0.03        0.0182177   0.2       ]
# Step 35, Pred state: [ 0.43215528  0.98915    -0.02578169  0.01967943  0.17150983], True state: [ 0.45        0.99791862 -0.03        0.0182177   0.16      ]
# Step 36, Pred state: [ 4.0822041e-01  9.8536980e-01 -1.3052106e-02  2.7537346e-05
#   8.5577257e-02], True state: [ 0.42        0.98386368 -0.03       -0.0182177   0.12      ]
# Step 37, Pred state: [ 0.40130484  0.9670958  -0.00306189  0.00406265  0.04832025], True state: [ 0.39        0.96564598 -0.03       -0.0182177   0.08      ]
# Step 38, Pred state: [ 3.65036905e-01  9.52114105e-01 -1.42297745e-02 -4.27305698e-04
#   1.87407676e-02], True state: [ 0.36        0.94742827 -0.03       -0.0182177   0.04      ]
# Step 39, Pred state: [ 0.3406486   0.93848735 -0.0020659  -0.00509149  0.00588836], True state: [ 3.30000000e-01  9.29210573e-01 -3.00000000e-02 -1.82177012e-02
#   9.71445147e-17]
# Step 40, Pred state: [ 0.3018307   0.9144666  -0.00474209 -0.01278251  0.01202454], True state: [ 0.3         0.91099287 -0.03       -0.0182177   0.        ]
# Step 41, Pred state: [ 0.27980465  0.8830861  -0.01189315 -0.01295716  0.01029425], True state: [ 0.27        0.89277517 -0.03       -0.0182177   0.        ]
# Step 42, Pred state: [ 0.24347065  0.87608916 -0.02360135 -0.00726342  0.01284537], True state: [ 0.24        0.87455747 -0.03       -0.0182177   0.        ]
# Step 43, Pred state: [ 0.22869155  0.8396237  -0.02614486 -0.01451087  0.01005655], True state: [ 0.21        0.85633977 -0.03       -0.0182177   0.        ]
# Step 44, Pred state: [ 0.17993203  0.83741534 -0.03575993 -0.00186759  0.01180673], True state: [ 0.18        0.83812207 -0.03       -0.0182177   0.        ]
# Step 45, Pred state: [ 0.14796045  0.8171006  -0.03553855 -0.0019353   0.01086967], True state: [ 0.15        0.81990437 -0.03       -0.0182177   0.        ]
# Step 46, Pred state: [ 0.12606667  0.7820089  -0.031169   -0.01614815  0.00942014], True state: [ 0.12        0.80168666 -0.03       -0.0182177   0.        ]
# Step 47, Pred state: [ 0.08088548  0.7918638  -0.03901732 -0.00184435  0.01024544], True state: [ 0.09        0.78346896 -0.03       -0.0182177   0.        ]
# Step 48, Pred state: [ 0.05858483  0.75989896 -0.03368092 -0.00319284  0.00884076], True state: [ 0.06        0.76525126 -0.03       -0.0182177   0.        ]
# Step 49, Pred state: [ 0.03106884  0.74391097 -0.03709131  0.00534451  0.00924012], True state: [ 0.03        0.74703356 -0.03       -0.0182177   0.        ]
# Step 50, Pred state: [ 0.00965598  0.69271106  0.02551448 -0.0125156   0.01047221], True state: [ 1.08246745e-15  7.28815859e-01  3.00000000e-02 -1.82177012e-02
#   0.00000000e+00]
# Step 51, Pred state: [ 0.03697663  0.67498505  0.01803672 -0.00938159  0.00773749], True state: [ 0.03        0.71059816  0.03       -0.0182177   0.        ]
# Step 52, Pred state: [0.07024167 0.6605755  0.00942314 0.01203811 0.008477  ], True state: [ 0.06        0.69238046  0.03       -0.0182177   0.        ]
# Step 53, Pred state: [0.08433443 0.6447659  0.01433957 0.01991415 0.00922297], True state: [ 0.09        0.67416276  0.03       -0.0182177   0.        ]
# Step 54, Pred state: [0.11453173 0.6131048  0.00839341 0.01677859 0.00958814], True state: [ 0.12        0.65594505  0.03       -0.0182177   0.        ]
# Step 55, Pred state: [0.15386276 0.57713926 0.01053846 0.00582767 0.00838377], True state: [ 0.15        0.63772735  0.03       -0.0182177   0.        ]
# Step 56, Pred state: [0.18656667 0.5583257  0.00818956 0.01412284 0.00934721], True state: [ 0.18        0.61950965  0.03       -0.0182177   0.        ]
# Step 57, Pred state: [0.22399735 0.54475945 0.00994098 0.00672472 0.00843312], True state: [ 0.21        0.60129195  0.03       -0.0182177   0.        ]
# Step 58, Pred state: [0.2453315  0.5463325  0.01210487 0.01428628 0.00931039], True state: [ 0.24        0.58307425  0.03       -0.0182177   0.        ]
# Step 59, Pred state: [0.2907642  0.5572961  0.02771115 0.01620495 0.00729805], True state: [ 0.27        0.56485655  0.03       -0.0182177   0.        ]
# Step 60, Pred state: [0.32821277 0.5593889  0.04242218 0.01931012 0.00661844], True state: [ 0.3         0.54663885  0.03       -0.0182177   0.        ]
# Step 61, Pred state: [0.34592107 0.5421725  0.03938007 0.01646447 0.00610002], True state: [ 0.33        0.52842115  0.03       -0.0182177   0.        ]
# Step 62, Pred state: [0.37073332 0.5289155  0.03132224 0.01005507 0.00531174], True state: [ 0.36        0.51020344  0.03       -0.0182177   0.        ]
# Step 63, Pred state: [0.40447956 0.51596475 0.03472757 0.00622833 0.00556337], True state: [ 0.39        0.49198574  0.03       -0.0182177   0.        ]
# Step 64, Pred state: [0.4255999  0.49003276 0.03667688 0.00151217 0.00563409], True state: [ 0.42        0.47376804  0.03       -0.0182177   0.        ]
# Step 65, Pred state: [ 0.44957903  0.47670153  0.02966845 -0.00293988  0.00708683], True state: [ 0.45        0.45555034  0.03       -0.0182177   0.        ]
# Step 66, Pred state: [ 0.4782911   0.45655152  0.01573753 -0.00131363  0.0093369 ], True state: [ 0.48        0.43733264  0.03       -0.0182177   0.        ]
# Step 67, Pred state: [ 0.5133969   0.4449691   0.01504159 -0.01056689  0.01216348], True state: [ 0.51        0.41911494  0.03       -0.0182177   0.        ]
# Step 68, Pred state: [ 0.5213779   0.42626664  0.01298583 -0.01374555  0.01055658], True state: [ 0.54        0.40089724  0.03       -0.0182177   0.        ]
# Step 69, Pred state: [ 0.54544324  0.42111453  0.01061749 -0.01704669  0.01036858], True state: [ 0.57        0.38267954  0.03       -0.0182177   0.        ]
# Step 70, Pred state: [ 0.56725585  0.40305313  0.00853229 -0.01809967  0.01198139], True state: [ 0.6         0.36446183  0.03       -0.0182177   0.        ]
# Step 71, Pred state: [ 0.60681593  0.3898425   0.00935924 -0.01509583  0.01313292], True state: [ 0.63        0.34624413  0.03       -0.0182177   0.        ]
# Step 72, Pred state: [ 0.6454617   0.37184674  0.00518    -0.01440686  0.01008291], True state: [ 0.66        0.32802643  0.03       -0.0182177   0.        ]
# Step 73, Pred state: [ 0.67004967  0.3484103   0.00495923 -0.01190716  0.00982076], True state: [ 0.69        0.30980873  0.03       -0.0182177   0.        ]
# Step 74, Pred state: [ 0.6868006   0.33047822  0.0099442  -0.01299071  0.01249171], True state: [ 0.72        0.29159103  0.03       -0.0182177   0.        ]
# Step 75, Pred state: [ 0.7255976   0.30404687  0.00737906 -0.01625454  0.01147481], True state: [ 0.75        0.27337333  0.03       -0.0182177   0.        ]
# Step 76, Pred state: [ 0.7575341   0.28663757  0.01137888 -0.01794565  0.01079841], True state: [ 0.78        0.25515563  0.03       -0.0182177   0.        ]
# Step 77, Pred state: [ 0.7876327   0.2766229   0.01291823 -0.02138335  0.01168453], True state: [ 0.81        0.23693793  0.03       -0.0182177   0.        ]
# Step 78, Pred state: [ 0.82261014  0.25640082  0.00731003 -0.02122122  0.01480463], True state: [ 0.84        0.21872022  0.03       -0.0182177   0.        ]
# Step 79, Pred state: [ 0.84390414  0.2610578   0.0059253  -0.02579981  0.01195323], True state: [ 0.87        0.20050252  0.03       -0.0182177   0.        ]
# Step 80, Pred state: [ 0.87224126  0.22928008 -0.00488794 -0.04074895  0.00935754], True state: [ 0.9         0.18228482  0.03       -0.0182177   0.        ]
# Step 81, Pred state: [ 0.8847861   0.17869449 -0.00890714 -0.03297132  0.01283709], True state: [ 0.93        0.16406712  0.03       -0.0182177   0.        ]
# Step 82, Pred state: [ 0.9382438   0.18252929  0.00640345 -0.02527118  0.01727415], True state: [ 0.96        0.14584942  0.03       -0.0182177   0.        ]
# Step 83, Pred state: [ 0.9931357   0.13685696  0.00834155 -0.02213287  0.0122545 ], True state: [ 0.99        0.12763172  0.03       -0.0182177   0.        ]
# Step 84, Pred state: [ 0.955671    0.1953471   0.00762379 -0.00687855  0.00287406], True state: [ 0.98        0.10941402 -0.03       -0.0320305   0.        ]
# Step 85, Pred state: [0.99394643 0.124669   0.01583326 0.00592613 0.0019964 ], True state: [ 0.95        0.07738352 -0.03       -0.0320305   0.        ]
# Step 86, Pred state: [0.95791036 0.09066914 0.01328993 0.0164361  0.01160519], True state: [ 0.92        0.04535302 -0.03       -0.0320305   0.        ]
# Step 87, Pred state: [0.9021039  0.15066414 0.01333559 0.02714193 0.00783808], True state: [ 0.89        0.01332252 -0.03       -0.0320305   0.        ]
# Step 88, Pred state: [0.9068238  0.045253   0.0150528  0.03239787 0.00667528], True state: [ 0.86        0.01870798 -0.03        0.0320305   0.        ]
# Step 89, Pred state: [0.8440164  0.02966784 0.0210892  0.02004874 0.03173042], True state: [ 0.83        0.05073848 -0.03        0.0320305   0.04      ]
# Step 90, Pred state: [ 0.8118641   0.05967438  0.01130617 -0.0080325   0.04555812], True state: [ 0.8         0.08276897 -0.03        0.0320305   0.08      ]
# Step 91, Pred state: [ 0.7722474   0.11561747  0.01275694 -0.01139945  0.07595269], True state: [ 0.77        0.11479947 -0.03        0.0320305   0.12      ]
# Step 92, Pred state: [ 7.7302969e-01  1.2683798e-01  5.9939623e-03 -5.9115887e-04
#   9.7736277e-02], True state: [ 0.74        0.14682997 -0.03        0.0320305   0.12      ]
# Step 93, Pred state: [ 0.76326495  0.13440834  0.00550854 -0.00210249  0.11125752], True state: [ 0.71        0.17886047 -0.03        0.0320305   0.12      ]
# Step 94, Pred state: [0.71752036 0.23980294 0.02754152 0.04320431 0.10733684], True state: [ 0.68        0.21089097 -0.03        0.0320305   0.12      ]
# Step 95, Pred state: [0.7162057  0.27745208 0.0274272  0.02929783 0.07085123], True state: [ 0.65        0.24292147 -0.03        0.0320305   0.08      ]
# Step 96, Pred state: [ 0.6625386   0.27629656  0.01593184 -0.00332487  0.03200309], True state: [ 0.62        0.27495196 -0.03        0.0320305   0.04      ]
# Step 97, Pred state: [0.5919741  0.3516152  0.01366556 0.03522718 0.00624636], True state: [ 0.59        0.30698246 -0.03        0.0320305   0.        ]
# Step 98, Pred state: [0.55959296 0.3698477  0.0150249  0.01699769 0.00803053], True state: [ 0.56        0.33901296 -0.03        0.0320305   0.        ]
# Step 99, Pred state: [0.554337   0.40441123 0.01155233 0.00639367 0.00888266], True state: [ 0.53        0.37104346 -0.03        0.0320305   0.        ]

# %% [markdown]
# The policy is near optimal, except missing the last volley, due to imperfections in the learned model. Adding more data and incorporating model robustness could improve the result further.
